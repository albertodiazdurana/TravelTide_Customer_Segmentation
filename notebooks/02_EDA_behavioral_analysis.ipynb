# %% [markdown]
# # TravelTide Customer Segmentation Project
# ## 02_EDA_behavioral_analysis.ipynb
#
# **Author:** Alberto Diaz Durana
# **Date:** October 2025
# **Purpose:** Behavioral analysis and user-level aggregation
#
# ---
#
# ## Objectives
#
# This notebook consolidates Week 1 Days 4-5 work to analyze customer behavior patterns and create user-level aggregations.
#
# **Mission:** Understand demographics, booking patterns, temporal trends, and aggregate session-level data to user-level metrics
#
# ## Business Context
#
# **From Notebook 01:** We established a cohort of 5,765 qualified users with 43,344 clean sessions.
#
# **Now:** Analyze behavioral patterns to identify segmentation opportunities and prepare user-level features.
#
# **Key Questions:**
# - Who are our customers? (demographics)
# - What do they book? (flights, hotels, packages)
# - When do they book? (seasonality, timing)
# - How engaged are they? (session patterns, conversion)
#
# **Deliverables:**
# - Demographic insights
# - Booking behavior analysis
# - Temporal pattern identification
# - User-level aggregated dataset
# - Preliminary CLV analysis
#
# **Outputs:**
# - `../data/processed/user_base_complete.csv`
# - `../data/results/eda/eda_summary_stats.csv`
# - `../outputs/figures/eda/` (8-10 visualizations)
#
# ---

# %% [markdown]
# ## 1. Setup & Load Cohort Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Visualization settings
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (14, 6)

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# Path constants
DATA_RAW = '../data/raw/'
DATA_PROCESSED = '../data/processed/'
DATA_RESULTS_EDA = '../data/results/eda/'
FIGURES_EDA = '../outputs/figures/eda/'

# Ensure directories exist
import os
os.makedirs(DATA_PROCESSED, exist_ok=True)
os.makedirs(DATA_RESULTS_EDA, exist_ok=True)
os.makedirs(FIGURES_EDA, exist_ok=True)

print(f"02_EDA_behavioral_analysis.ipynb - {datetime.now().strftime('%Y-%m-%d')}")
print("="*80)

# %%
print("LOADING COHORT DATA FROM NOTEBOOK 01")
print("="*80)

# Load cleaned cohort from notebook 01
session_base = pd.read_csv(f'{DATA_RESULTS_EDA}eda_cohort_qualified.csv')

# Convert date columns
date_columns = ['birthdate', 'sign_up_date', 'session_start', 'session_end', 
                'departure_time', 'return_time', 'check_in_time', 'check_out_time']
for col in date_columns:
    if col in session_base.columns:
        session_base[col] = pd.to_datetime(session_base[col])

print(f"\nOK: Cohort data loaded")
print(f"  Shape: {session_base.shape}")
print(f"  Sessions: {len(session_base):,}")
print(f"  Users: {session_base['user_id'].nunique():,}")
print(f"  Date range: {session_base['session_start'].min().date()} to {session_base['session_start'].max().date()}")

# Quick validation
print("\nData Validation:")
print(f"  Missing user_id: {session_base['user_id'].isna().sum()}")
print(f"  Missing session_id: {session_base['session_id'].isna().sum()}")
print(f"  Age range: {session_base['age'].min():.0f}-{session_base['age'].max():.0f} years")

print("\n" + "="*80)

# %% [markdown]
# ## 2. Demographic Analysis
#
# Understanding who our customers are: age, gender, family status, location, and tenure.

# %%
print("DEMOGRAPHIC ANALYSIS")
print("="*80)

# Get unique users (one row per user)
users = session_base.groupby('user_id').first().reset_index()

print(f"\nTotal Users: {len(users):,}")

# Age distribution
print("\nAGE DISTRIBUTION:")
print("-" * 80)
print(f"  Mean: {users['age'].mean():.1f} years")
print(f"  Median: {users['age'].median():.0f} years")
print(f"  Std Dev: {users['age'].std():.1f} years")
print(f"  Range: {users['age'].min():.0f}-{users['age'].max():.0f} years")

# Age groups
age_bins = [18, 25, 35, 45, 55, 65, 100]
age_labels = ['18-24', '25-34', '35-44', '45-54', '55-64', '65+']
users['age_group'] = pd.cut(users['age'], bins=age_bins, labels=age_labels, right=False)

print("\nAge Group Distribution:")
age_dist = users['age_group'].value_counts().sort_index()
for group, count in age_dist.items():
    pct = count / len(users) * 100
    print(f"  {group}: {count:,} ({pct:.1f}%)")

# Gender distribution
print("\nGENDER DISTRIBUTION:")
print("-" * 80)
gender_dist = users['gender'].value_counts()
for gender, count in gender_dist.items():
    pct = count / len(users) * 100
    print(f"  {gender}: {count:,} ({pct:.1f}%)")

# Family status
print("\nFAMILY STATUS:")
print("-" * 80)
married_count = users['married'].sum()
children_count = users['has_children'].sum()
print(f"  Married: {married_count:,} ({married_count/len(users)*100:.1f}%)")
print(f"  Has Children: {children_count:,} ({children_count/len(users)*100:.1f}%)")

# Tenure (days since signup)
users['days_since_signup'] = (pd.Timestamp('2023-04-30') - users['sign_up_date']).dt.days
users['years_active'] = users['days_since_signup'] / 365.25

print("\nTENURE (Account Age):")
print("-" * 80)
print(f"  Mean: {users['years_active'].mean():.2f} years")
print(f"  Median: {users['years_active'].median():.2f} years")
print(f"  Range: {users['years_active'].min():.2f}-{users['years_active'].max():.2f} years")

print("\nOK: Demographic analysis complete")

# %%
# Demographic visualizations
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# Plot 1: Age distribution
axes[0, 0].hist(users['age'], bins=30, color='steelblue', edgecolor='black', alpha=0.7)
axes[0, 0].axvline(users['age'].mean(), color='red', linestyle='--', linewidth=2,
                   label=f"Mean: {users['age'].mean():.1f}")
axes[0, 0].axvline(users['age'].median(), color='orange', linestyle='--', linewidth=2,
                   label=f"Median: {users['age'].median():.0f}")
axes[0, 0].set_xlabel('Age (years)', fontweight='bold')
axes[0, 0].set_ylabel('Number of Users', fontweight='bold')
axes[0, 0].set_title('Age Distribution', fontweight='bold', fontsize=12)
axes[0, 0].legend()
axes[0, 0].grid(axis='y', alpha=0.3)

# Plot 2: Age groups
age_dist.plot(kind='bar', ax=axes[0, 1], color='teal', edgecolor='black', alpha=0.7)
axes[0, 1].set_xlabel('Age Group', fontweight='bold')
axes[0, 1].set_ylabel('Number of Users', fontweight='bold')
axes[0, 1].set_title('Users by Age Group', fontweight='bold', fontsize=12)
axes[0, 1].tick_params(axis='x', rotation=45)
axes[0, 1].grid(axis='y', alpha=0.3)

# Plot 3: Gender distribution
gender_dist.plot(kind='bar', ax=axes[0, 2], color=['#FF69B4', '#4169E1', '#9370DB'], 
                 edgecolor='black', alpha=0.7)
axes[0, 2].set_xlabel('Gender', fontweight='bold')
axes[0, 2].set_ylabel('Number of Users', fontweight='bold')
axes[0, 2].set_title('Gender Distribution', fontweight='bold', fontsize=12)
axes[0, 2].tick_params(axis='x', rotation=0)
axes[0, 2].grid(axis='y', alpha=0.3)

# Plot 4: Family status
family_data = pd.DataFrame({
    'Category': ['Married', 'Single', 'Has Children', 'No Children'],
    'Count': [married_count, len(users) - married_count, 
              children_count, len(users) - children_count]
})
family_colors = ['#2ecc71', '#e74c3c', '#3498db', '#e67e22']
axes[1, 0].bar(family_data['Category'], family_data['Count'], 
               color=family_colors, edgecolor='black', alpha=0.7)
axes[1, 0].set_ylabel('Number of Users', fontweight='bold')
axes[1, 0].set_title('Family Status', fontweight='bold', fontsize=12)
axes[1, 0].tick_params(axis='x', rotation=45)
axes[1, 0].grid(axis='y', alpha=0.3)

# Plot 5: Tenure distribution
axes[1, 1].hist(users['years_active'], bins=30, color='darkorange', edgecolor='black', alpha=0.7)
axes[1, 1].axvline(users['years_active'].mean(), color='red', linestyle='--', linewidth=2,
                   label=f"Mean: {users['years_active'].mean():.2f} yrs")
axes[1, 1].set_xlabel('Years Active', fontweight='bold')
axes[1, 1].set_ylabel('Number of Users', fontweight='bold')
axes[1, 1].set_title('Account Tenure Distribution', fontweight='bold', fontsize=12)
axes[1, 1].legend()
axes[1, 1].grid(axis='y', alpha=0.3)

# Plot 6: Top countries
top_countries = users['home_country'].value_counts().head(10)
top_countries.plot(kind='barh', ax=axes[1, 2], color='purple', edgecolor='black', alpha=0.7)
axes[1, 2].set_xlabel('Number of Users', fontweight='bold')
axes[1, 2].set_title('Top 10 Countries', fontweight='bold', fontsize=12)
axes[1, 2].grid(axis='x', alpha=0.3)

plt.suptitle('Customer Demographics Overview', fontweight='bold', fontsize=14, y=1.00)
plt.tight_layout()
plt.savefig(f'{FIGURES_EDA}eda_demographics.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"\nOK: Saved: {FIGURES_EDA}eda_demographics.png")

# %% [markdown]
# ## 3. Booking Behavior & Pattern Analysis
#
# Understanding what customers book: flights, hotels, packages, cancellations, and trip characteristics.

# %%
print("BOOKING BEHAVIOR ANALYSIS")
print("="*80)

# Session-level booking metrics
print("\nSESSION-LEVEL METRICS:")
print("-" * 80)
total_sessions = len(session_base)
flight_bookings = session_base['flight_booked'].sum()
hotel_bookings = session_base['hotel_booked'].sum()
cancellations = session_base['cancellation'].sum()

print(f"  Total sessions: {total_sessions:,}")
print(f"  Flight bookings: {flight_bookings:,} ({flight_bookings/total_sessions*100:.2f}%)")
print(f"  Hotel bookings: {hotel_bookings:,} ({hotel_bookings/total_sessions*100:.2f}%)")
print(f"  Cancellations: {cancellations:,} ({cancellations/total_sessions*100:.2f}%)")

# Both flight and hotel in same session
both_bookings = ((session_base['flight_booked']) & (session_base['hotel_booked'])).sum()
print(f"  Package bookings (flight + hotel): {both_bookings:,} ({both_bookings/total_sessions*100:.2f}%)")

# User-level booking patterns
print("\nUSER-LEVEL BOOKING PATTERNS:")
print("-" * 80)

user_booking_stats = session_base.groupby('user_id').agg({
    'flight_booked': 'sum',
    'hotel_booked': 'sum',
    'cancellation': 'sum',
    'session_id': 'count'
}).rename(columns={'session_id': 'total_sessions'})

print(f"  Users with flight bookings: {(user_booking_stats['flight_booked'] > 0).sum():,} "
      f"({(user_booking_stats['flight_booked'] > 0).sum()/len(users)*100:.1f}%)")
print(f"  Users with hotel bookings: {(user_booking_stats['hotel_booked'] > 0).sum():,} "
      f"({(user_booking_stats['hotel_booked'] > 0).sum()/len(users)*100:.1f}%)")
print(f"  Users with cancellations: {(user_booking_stats['cancellation'] > 0).sum():,} "
      f"({(user_booking_stats['cancellation'] > 0).sum()/len(users)*100:.1f}%)")

# Average bookings per user
print(f"\n  Avg flights per user: {user_booking_stats['flight_booked'].mean():.2f}")
print(f"  Avg hotels per user: {user_booking_stats['hotel_booked'].mean():.2f}")
print(f"  Avg cancellations per user: {user_booking_stats['cancellation'].mean():.2f}")

# Trip characteristics (for bookings only)
print("\nTRIP CHARACTERISTICS (Bookings Only):")
print("-" * 80)

# Flight characteristics
flights = session_base[session_base['flight_booked'] == True]
if len(flights) > 0:
    print(f"  Flights booked: {len(flights):,}")
    print(f"  Avg fare: ${flights["base_fare_usd"].mean():.2f}")
    print(f"  Median fare: ${flights["base_fare_usd"].median():.2f}")
    print(f"  Avg seats per flight: {flights["seats"].mean():.2f}")
    print(f"  Avg bags per flight: {flights["bags"].mean():.2f}")
    print(f"  Return flights: {flights["return_flight_booked"].sum():,} ({flights["return_flight_booked"].sum()/len(flights)*100:.1f}%)")

# Hotel characteristics
hotels = session_base[session_base['hotel_booked'] == True]
if len(hotels) > 0:
    print(f"\n  Hotels booked: {len(hotels):,}")
    print(f"  Avg price per night: ${hotels["hotel_price_per_room_night_usd"].mean():.2f}")
    print(f"  Median price per night: ${hotels["hotel_price_per_room_night_usd"].median():.2f}")
    print(f"  Avg nights per stay: {hotels["nights"].mean():.2f}")
    print(f"  Avg rooms per booking: {hotels["rooms"].mean():.2f}")

print("\nOK: Booking behavior analysis complete")

# %%
# Booking behavior visualizations
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# Plot 1: Booking conversion rates
conversion_data = pd.DataFrame({
    'Type': ['Flights', 'Hotels', 'Packages', 'Cancellations'],
    'Rate': [flight_bookings/total_sessions*100, 
             hotel_bookings/total_sessions*100,
             both_bookings/total_sessions*100,
             cancellations/total_sessions*100]
})
colors_conv = ['#3498db', '#e74c3c', '#2ecc71', '#95a5a6']
axes[0, 0].bar(conversion_data['Type'], conversion_data['Rate'], 
               color=colors_conv, edgecolor='black', alpha=0.7)
axes[0, 0].set_ylabel('Conversion Rate (%)', fontweight='bold')
axes[0, 0].set_title('Session-Level Conversion Rates', fontweight='bold', fontsize=12)
axes[0, 0].tick_params(axis='x', rotation=45)
axes[0, 0].grid(axis='y', alpha=0.3)

# Plot 2: Bookings per user distribution
axes[0, 1].hist(user_booking_stats['flight_booked'], bins=20, alpha=0.6, 
                color='blue', label='Flights', edgecolor='black')
axes[0, 1].hist(user_booking_stats['hotel_booked'], bins=20, alpha=0.6, 
                color='red', label='Hotels', edgecolor='black')
axes[0, 1].set_xlabel('Number of Bookings per User', fontweight='bold')
axes[0, 1].set_ylabel('Number of Users', fontweight='bold')
axes[0, 1].set_title('Bookings per User Distribution', fontweight='bold', fontsize=12)
axes[0, 1].legend()
axes[0, 1].grid(axis='y', alpha=0.3)

# Plot 3: Flight fare distribution
axes[0, 2].hist(flights['base_fare_usd'].dropna(), bins=30, color='darkblue', 
                edgecolor='black', alpha=0.7)
axes[0, 2].axvline(flights['base_fare_usd'].mean(), color='red', linestyle='--', 
                   linewidth=2, label=f"Mean: ${flights['base_fare_usd'].mean():.0f}")
axes[0, 2].axvline(flights['base_fare_usd'].median(), color='orange', linestyle='--', 
                   linewidth=2, label=f"Median: ${flights['base_fare_usd'].median():.0f}")
axes[0, 2].set_xlabel('Flight Fare (USD)', fontweight='bold')
axes[0, 2].set_ylabel('Number of Bookings', fontweight='bold')
axes[0, 2].set_title('Flight Fare Distribution', fontweight='bold', fontsize=12)
axes[0, 2].legend()
axes[0, 2].grid(axis='y', alpha=0.3)

# Plot 4: Hotel price distribution
axes[1, 0].hist(hotels['hotel_price_per_room_night_usd'].dropna(), bins=30, 
                color='darkred', edgecolor='black', alpha=0.7)
axes[1, 0].axvline(hotels['hotel_price_per_room_night_usd'].mean(), color='blue', 
                   linestyle='--', linewidth=2, 
                   label=f"Mean: ${hotels['hotel_price_per_room_night_usd'].mean():.0f}")
axes[1, 0].axvline(hotels['hotel_price_per_room_night_usd'].median(), color='orange', 
                   linestyle='--', linewidth=2, 
                   label=f"Median: ${hotels['hotel_price_per_room_night_usd'].median():.0f}")
axes[1, 0].set_xlabel('Hotel Price per Night (USD)', fontweight='bold')
axes[1, 0].set_ylabel('Number of Bookings', fontweight='bold')
axes[1, 0].set_title('Hotel Price Distribution', fontweight='bold', fontsize=12)
axes[1, 0].legend()
axes[1, 0].grid(axis='y', alpha=0.3)

# Plot 5: Nights per stay distribution (CORRECTED)
axes[1, 1].hist(hotels['nights'].dropna(), bins=range(int(hotels['nights'].min()), 
                int(hotels['nights'].max()) + 2), color='teal', 
                edgecolor='black', alpha=0.7)
axes[1, 1].axvline(hotels['nights'].mean(), color='red', linestyle='--', 
                   linewidth=2, label=f"Mean: {hotels['nights'].mean():.1f}")
axes[1, 1].set_xlabel('Nights per Stay', fontweight='bold')
axes[1, 1].set_ylabel('Number of Bookings', fontweight='bold')
axes[1, 1].set_title('Hotel Nights Distribution', fontweight='bold', fontsize=12)
# Set integer ticks on x-axis
axes[1, 1].set_xticks(range(int(hotels['nights'].min()), 
                             min(int(hotels['nights'].max()) + 1, 15)))
axes[1, 1].legend()
axes[1, 1].grid(axis='y', alpha=0.3)

# Plot 6: Top destinations
top_destinations = flights['destination_airport'].value_counts().head(10)
top_destinations.plot(kind='barh', ax=axes[1, 2], color='purple', 
                      edgecolor='black', alpha=0.7)
axes[1, 2].set_xlabel('Number of Flights', fontweight='bold')
axes[1, 2].set_title('Top 10 Destinations', fontweight='bold', fontsize=12)
axes[1, 2].grid(axis='x', alpha=0.3)

plt.suptitle('Booking Behavior & Trip Characteristics', fontweight='bold', fontsize=14, y=1.00)
plt.tight_layout()
plt.savefig(f'{FIGURES_EDA}eda_booking_behavior.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"\nOK: Saved: {FIGURES_EDA}eda_booking_behavior.png")

# %% [markdown]
# ## 4. Session Engagement & Temporal Patterns
#
# Understanding when and how customers engage: page clicks, session duration, timing patterns.

# %%
print("SESSION ENGAGEMENT ANALYSIS")
print("="*80)

# Page clicks analysis
print("\nPAGE CLICKS PER SESSION:")
print("-" * 80)
print(f"  Mean: {session_base['page_clicks'].mean():.2f}")
print(f"  Median: {session_base['page_clicks'].median():.0f}")
print(f"  Std Dev: {session_base['page_clicks'].std():.2f}")
print(f"  Range: {session_base['page_clicks'].min():.0f}-{session_base['page_clicks'].max():.0f}")

# Session duration (if available)
if 'session_start' in session_base.columns and 'session_end' in session_base.columns:
    session_base['session_duration_minutes'] = (
        session_base['session_end'] - session_base['session_start']
    ).dt.total_seconds() / 60
    
    print("\nSESSION DURATION:")
    print("-" * 80)
    print(f"  Mean: {session_base['session_duration_minutes'].mean():.2f} minutes")
    print(f"  Median: {session_base['session_duration_minutes'].median():.2f} minutes")
    print(f"  Range: {session_base['session_duration_minutes'].min():.2f}-{session_base['session_duration_minutes'].max():.2f} minutes")

# Engagement by booking status
print("\nENGAGEMENT BY BOOKING STATUS:")
print("-" * 80)
booking_engagement = session_base.groupby('flight_booked')['page_clicks'].agg(['mean', 'median'])
print("\nFlight Booking:")
print(f"  Booked - Mean clicks: {booking_engagement.loc[True, 'mean']:.2f}, Median: {booking_engagement.loc[True, 'median']:.0f}")
print(f"  Not booked - Mean clicks: {booking_engagement.loc[False, 'mean']:.2f}, Median: {booking_engagement.loc[False, 'median']:.0f}")

# Temporal patterns - day of week
session_base['day_of_week'] = session_base['session_start'].dt.day_name()
session_base['hour_of_day'] = session_base['session_start'].dt.hour
session_base['month'] = session_base['session_start'].dt.month

print("\nSESSIONS BY DAY OF WEEK:")
print("-" * 80)
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_counts = session_base['day_of_week'].value_counts().reindex(day_order)
for day, count in day_counts.items():
    pct = count / len(session_base) * 100
    print(f"  {day}: {count:,} ({pct:.1f}%)")

print("\nSESSIONS BY MONTH:")
print("-" * 80)
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul']
month_counts = session_base['month'].value_counts().sort_index()
for month, count in month_counts.items():
    pct = count / len(session_base) * 100
    print(f"  {month_names[month-1]}: {count:,} ({pct:.1f}%)")

print("\nSESSIONS BY HOUR OF DAY:")
print("-" * 80)
hour_counts = session_base['hour_of_day'].value_counts().sort_index()
for hour, count in hour_counts.items():
    pct = count / len(session_base) * 100
    print(f"  {hour:02d}:00 - {count:,} ({pct:.1f}%)")

print("\nOK: Session engagement analysis complete")

# %%
# Engagement and temporal pattern visualizations
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# Plot 1: Page clicks distribution
axes[0, 0].hist(session_base['page_clicks'], bins=30, color='steelblue', 
                edgecolor='black', alpha=0.7)
axes[0, 0].axvline(session_base['page_clicks'].mean(), color='red', linestyle='--', 
                   linewidth=2, label=f"Mean: {session_base['page_clicks'].mean():.1f}")
axes[0, 0].axvline(session_base['page_clicks'].median(), color='orange', linestyle='--', 
                   linewidth=2, label=f"Median: {session_base['page_clicks'].median():.0f}")
axes[0, 0].set_xlabel('Page Clicks per Session', fontweight='bold')
axes[0, 0].set_ylabel('Number of Sessions', fontweight='bold')
axes[0, 0].set_title('Page Clicks Distribution', fontweight='bold', fontsize=12)
axes[0, 0].legend()
axes[0, 0].grid(axis='y', alpha=0.3)

# Plot 2: Session duration distribution
axes[0, 1].hist(session_base['session_duration_minutes'], bins=200, color='darkgreen', 
                edgecolor='black', alpha=0.7)
axes[0, 1].axvline(session_base['session_duration_minutes'].mean(), color='red', 
                   linestyle='--', linewidth=2, 
                   label=f"Mean: {session_base['session_duration_minutes'].mean():.1f} min")
axes[0, 1].set_xlabel('Session Duration (minutes)', fontweight='bold')
axes[0, 1].set_ylabel('Number of Sessions', fontweight='bold')
axes[0, 1].set_title('Session Duration Distribution', fontweight='bold', fontsize=12)
axes[0, 1].legend()
axes[0, 1].grid(axis='y', alpha=0.3)

# Plot 3: Clicks by booking status
booking_comparison = pd.DataFrame({
    'Status': ['Booked', 'Not Booked'],
    'Mean_Clicks': [booking_engagement.loc[True, 'mean'], 
                    booking_engagement.loc[False, 'mean']]
})
axes[0, 2].bar(booking_comparison['Status'], booking_comparison['Mean_Clicks'], 
               color=['#2ecc71', '#e74c3c'], edgecolor='black', alpha=0.7)
axes[0, 2].set_ylabel('Mean Page Clicks', fontweight='bold')
axes[0, 2].set_title('Engagement: Booked vs Non-Booked Sessions', fontweight='bold', fontsize=12)
axes[0, 2].grid(axis='y', alpha=0.3)

# Plot 4: Sessions by day of week
day_counts.plot(kind='bar', ax=axes[1, 0], color='purple', edgecolor='black', alpha=0.7)
axes[1, 0].set_xlabel('Day of Week', fontweight='bold')
axes[1, 0].set_ylabel('Number of Sessions', fontweight='bold')
axes[1, 0].set_title('Sessions by Day of Week', fontweight='bold', fontsize=12)
axes[1, 0].tick_params(axis='x', rotation=45)
axes[1, 0].grid(axis='y', alpha=0.3)

# Plot 5: Sessions by month
month_counts.plot(kind='bar', ax=axes[1, 1], color='darkorange', edgecolor='black', alpha=0.7)
axes[1, 1].set_xlabel('Month (2023)', fontweight='bold')
axes[1, 1].set_ylabel('Number of Sessions', fontweight='bold')
axes[1, 1].set_title('Sessions by Month (Seasonality)', fontweight='bold', fontsize=12)
axes[1, 1].set_xticklabels(month_names[:len(month_counts)], rotation=0)
axes[1, 1].grid(axis='y', alpha=0.3)

# Plot 6: Sessions by hour of day
hour_counts = session_base['hour_of_day'].value_counts().sort_index()
hour_counts.plot(kind='line', ax=axes[1, 2], color='teal', marker='o', linewidth=2)
axes[1, 2].set_xlabel('Hour of Day (24h)', fontweight='bold')
axes[1, 2].set_ylabel('Number of Sessions', fontweight='bold')
axes[1, 2].set_title('Sessions by Hour of Day', fontweight='bold', fontsize=12)
axes[1, 2].grid(alpha=0.3)
axes[1, 2].set_xticks(range(0, 24, 2))

plt.suptitle('Session Engagement & Temporal Patterns', fontweight='bold', fontsize=14, y=1.00)
plt.tight_layout()
plt.savefig(f'{FIGURES_EDA}eda_engagement_temporal.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"\nOK: Saved: {FIGURES_EDA}eda_engagement_temporal.png")

# %% [markdown]
# ### 4.1 Outlier Investigation: Session Duration & Page Clicks
#
# Detailed analysis of potential outliers in engagement metrics that may affect analysis quality.

# %%
print("INVESTIGATING POTENTIAL OUTLIERS IN ENGAGEMENT METRICS")
print("="*80)

# Function to detect and analyze outliers
def analyze_outliers_detailed(data, column, multiplier=3.0):
    """
    Detailed outlier analysis with statistics and visualization recommendations.
    """
    values = data[column].dropna()
    
    Q1 = values.quantile(0.25)
    Q3 = values.quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - (multiplier * IQR)
    upper_bound = Q3 + (multiplier * IQR)
    
    outliers_mask = (values < lower_bound) | (values > upper_bound)
    outliers = values[outliers_mask]
    
    print(f"\n{column.upper()} ANALYSIS:")
    print("-" * 80)
    print(f"  Total records: {len(values):,}")
    print(f"  Q1 (25th percentile): {Q1:.2f}")
    print(f"  Q3 (75th percentile): {Q3:.2f}")
    print(f"  IQR: {IQR:.2f}")
    print(f"  Lower bound: {lower_bound:.2f}")
    print(f"  Upper bound: {upper_bound:.2f}")
    
    print(f"\n  OUTLIERS DETECTED:")
    print(f"    Count: {len(outliers):,} ({len(outliers)/len(values)*100:.2f}%)")
    if len(outliers) > 0:
        print(f"    Min outlier: {outliers.min():.2f}")
        print(f"    Max outlier: {outliers.max():.2f}")
        print(f"    Mean outlier: {outliers.mean():.2f}")
    
    print(f"\n  WITH OUTLIERS:")
    print(f"    Mean: {values.mean():.2f}")
    print(f"    Median: {values.median():.2f}")
    print(f"    Std: {values.std():.2f}")
    print(f"    Range: {values.min():.2f} - {values.max():.2f}")
    
    if len(outliers) > 0:
        clean_values = values[~outliers_mask]
        print(f"\n  WITHOUT OUTLIERS:")
        print(f"    Mean: {clean_values.mean():.2f}")
        print(f"    Median: {clean_values.median():.2f}")
        print(f"    Std: {clean_values.std():.2f}")
        print(f"    Range: {clean_values.min():.2f} - {clean_values.max():.2f}")
        
        mean_diff = abs(values.mean() - clean_values.mean())
        mean_pct_change = (mean_diff / values.mean()) * 100
        print(f"\n  IMPACT OF REMOVAL:")
        print(f"    Mean change: {mean_diff:.2f} ({mean_pct_change:.1f}%)")
    
    return outliers_mask, lower_bound, upper_bound

# Analyze page_clicks
page_clicks_outliers, pc_lower, pc_upper = analyze_outliers_detailed(
    session_base, 'page_clicks', multiplier=3.0
)

# Analyze session_duration_minutes
duration_outliers, dur_lower, dur_upper = analyze_outliers_detailed(
    session_base, 'session_duration_minutes', multiplier=3.0
)

# Show extreme examples
print("\n" + "="*80)
print("EXTREME EXAMPLES")
print("="*80)

print("\nTOP 10 LONGEST SESSIONS:")
top_duration = session_base.nlargest(10, 'session_duration_minutes')[
    ['user_id', 'session_id', 'session_duration_minutes', 'page_clicks', 'flight_booked', 'hotel_booked']
]
print(top_duration.to_string(index=False))

print("\nTOP 10 HIGHEST PAGE CLICKS:")
top_clicks = session_base.nlargest(10, 'page_clicks')[
    ['user_id', 'session_id', 'page_clicks', 'session_duration_minutes', 'flight_booked', 'hotel_booked']
]
print(top_clicks.to_string(index=False))

print("\nOK: Outlier investigation complete")

# %%
print("REMOVING ENGAGEMENT OUTLIERS")
print("="*80)

# Store original size
original_sessions = len(session_base)

# Create combined outlier mask
outliers_to_remove = page_clicks_outliers | duration_outliers

# Remove outliers
session_base_clean = session_base[~outliers_to_remove].copy()

print(f"\nOUTLIER REMOVAL SUMMARY:")
print("-" * 80)
print(f"  Original sessions: {original_sessions:,}")
print(f"  Page clicks outliers: {page_clicks_outliers.sum():,}")
print(f"  Duration outliers: {duration_outliers.sum():,}")
print(f"  Total outliers removed: {outliers_to_remove.sum():,}")
print(f"  Final sessions: {len(session_base_clean):,}")
print(f"  Percentage removed: {outliers_to_remove.sum()/original_sessions*100:.2f}%")

# Update session_base to use cleaned version
session_base = session_base_clean.copy()

print(f"\nREVISED METRICS (After Outlier Removal):")
print("-" * 80)
print(f"  Page clicks - Mean: {session_base['page_clicks'].mean():.2f}, Median: {session_base['page_clicks'].median():.0f}")
print(f"  Session duration - Mean: {session_base['session_duration_minutes'].mean():.2f}, Median: {session_base['session_duration_minutes'].median():.2f}")

print("\nOK: Engagement outliers removed - session_base updated")

# %%
# Engagement and temporal pattern visualizations
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# Plot 1: Page clicks distribution
axes[0, 0].hist(session_base['page_clicks'], bins=30, color='steelblue', 
                edgecolor='black', alpha=0.7)
axes[0, 0].axvline(session_base['page_clicks'].mean(), color='red', linestyle='--', 
                   linewidth=2, label=f"Mean: {session_base['page_clicks'].mean():.1f}")
axes[0, 0].axvline(session_base['page_clicks'].median(), color='orange', linestyle='--', 
                   linewidth=2, label=f"Median: {session_base['page_clicks'].median():.0f}")
axes[0, 0].set_xlabel('Page Clicks per Session', fontweight='bold')
axes[0, 0].set_ylabel('Number of Sessions', fontweight='bold')
axes[0, 0].set_title('Page Clicks Distribution', fontweight='bold', fontsize=12)
axes[0, 0].legend()
axes[0, 0].grid(axis='y', alpha=0.3)

# Plot 2: Session duration distribution
axes[0, 1].hist(session_base['session_duration_minutes'], bins=50, color='darkgreen', 
                edgecolor='black', alpha=0.7)
axes[0, 1].axvline(session_base['session_duration_minutes'].mean(), color='red', 
                   linestyle='--', linewidth=2, 
                   label=f"Mean: {session_base['session_duration_minutes'].mean():.1f} min")
axes[0, 1].set_xlabel('Session Duration (minutes)', fontweight='bold')
axes[0, 1].set_ylabel('Number of Sessions', fontweight='bold')
axes[0, 1].set_title('Session Duration Distribution', fontweight='bold', fontsize=12)
axes[0, 1].legend()
axes[0, 1].grid(axis='y', alpha=0.3)

# Plot 3: Clicks by booking status
booking_comparison = pd.DataFrame({
    'Status': ['Booked', 'Not Booked'],
    'Mean_Clicks': [booking_engagement.loc[True, 'mean'], 
                    booking_engagement.loc[False, 'mean']]
})
axes[0, 2].bar(booking_comparison['Status'], booking_comparison['Mean_Clicks'], 
               color=['#2ecc71', '#e74c3c'], edgecolor='black', alpha=0.7)
axes[0, 2].set_ylabel('Mean Page Clicks', fontweight='bold')
axes[0, 2].set_title('Engagement: Booked vs Non-Booked Sessions', fontweight='bold', fontsize=12)
axes[0, 2].grid(axis='y', alpha=0.3)

# Plot 4: Sessions by day of week
day_counts.plot(kind='bar', ax=axes[1, 0], color='purple', edgecolor='black', alpha=0.7)
axes[1, 0].set_xlabel('Day of Week', fontweight='bold')
axes[1, 0].set_ylabel('Number of Sessions', fontweight='bold')
axes[1, 0].set_title('Sessions by Day of Week', fontweight='bold', fontsize=12)
axes[1, 0].tick_params(axis='x', rotation=45)
axes[1, 0].grid(axis='y', alpha=0.3)

# Plot 5: Sessions by month
month_counts.plot(kind='bar', ax=axes[1, 1], color='darkorange', edgecolor='black', alpha=0.7)
axes[1, 1].set_xlabel('Month (2023)', fontweight='bold')
axes[1, 1].set_ylabel('Number of Sessions', fontweight='bold')
axes[1, 1].set_title('Sessions by Month (Seasonality)', fontweight='bold', fontsize=12)
axes[1, 1].set_xticklabels(month_names[:len(month_counts)], rotation=0)
axes[1, 1].grid(axis='y', alpha=0.3)

# Plot 6: Sessions by hour of day
hour_counts = session_base['hour_of_day'].value_counts().sort_index()
hour_counts.plot(kind='line', ax=axes[1, 2], color='teal', marker='o', linewidth=2)
axes[1, 2].set_xlabel('Hour of Day (24h)', fontweight='bold')
axes[1, 2].set_ylabel('Number of Sessions', fontweight='bold')
axes[1, 2].set_title('Sessions by Hour of Day', fontweight='bold', fontsize=12)
axes[1, 2].grid(alpha=0.3)
axes[1, 2].set_xticks(range(0, 24, 2))

plt.suptitle('Session Engagement & Temporal Patterns', fontweight='bold', fontsize=14, y=1.00)
plt.tight_layout()
plt.savefig(f'{FIGURES_EDA}eda_engagement_temporal.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"\nOK: Saved: {FIGURES_EDA}eda_engagement_temporal.png")

# %% [markdown]
# ## 5. User-Level Aggregation
#
# Transform session-level data into user-level features for segmentation analysis.

# %%
print("AGGREGATING SESSION DATA TO USER LEVEL")
print("="*80)

# Basic user information (one row per user)
user_info = session_base.groupby('user_id').agg({
    'birthdate': 'first',
    'gender': 'first',
    'married': 'first',
    'has_children': 'first',
    'home_country': 'first',
    'home_city': 'first',
    'home_airport': 'first',
    'sign_up_date': 'first',
    'age': 'first'
}).reset_index()

print(f"\nUser info aggregated: {len(user_info):,} users")

# Session metrics
session_metrics = session_base.groupby('user_id').agg({
    'session_id': 'count',
    'page_clicks': ['sum', 'mean'],
    'session_duration_minutes': ['mean', 'median']
}).reset_index()

# Flatten column names
session_metrics.columns = ['user_id', 'total_sessions', 'total_page_clicks', 
                           'avg_page_clicks_per_session', 'avg_session_duration_minutes',
                           'median_session_duration_minutes']

print(f"Session metrics aggregated: {len(session_metrics):,} users")

# Booking metrics
booking_metrics = session_base.groupby('user_id').agg({
    'flight_booked': 'sum',
    'hotel_booked': 'sum',
    'cancellation': 'sum'
}).reset_index()

booking_metrics.columns = ['user_id', 'total_flights_booked', 'total_hotels_booked', 
                           'total_cancellations']

print(f"Booking metrics aggregated: {len(booking_metrics):,} users")

# Package bookings (flight + hotel in same session)
package_bookings = session_base[
    (session_base['flight_booked']) & (session_base['hotel_booked'])
].groupby('user_id').size().reset_index(name='total_package_bookings')

print(f"Package bookings aggregated: {len(package_bookings):,} users with packages")

# Flight trip metrics (for users who booked flights)
flight_trips = session_base[session_base['flight_booked'] == True].groupby('user_id').agg({
    'base_fare_usd': ['sum', 'mean'],
    'seats': 'sum',
    'bags': ['sum', 'mean'],
    'return_flight_booked': 'sum'
}).reset_index()

flight_trips.columns = ['user_id', 'total_flight_spend', 'avg_flight_fare', 
                        'total_seats_purchased', 'total_bags', 'avg_bags_per_trip',
                        'return_flight_count']

print(f"Flight trip metrics aggregated: {len(flight_trips):,} users with flights")

# Hotel trip metrics (for users who booked hotels)
hotel_trips = session_base[session_base['hotel_booked'] == True].groupby('user_id').agg({
    'hotel_price_per_room_night_usd': ['sum', 'mean'],
    'nights': ['sum', 'mean'],
    'rooms': ['sum', 'mean']
}).reset_index()

hotel_trips.columns = ['user_id', 'total_hotel_spend', 'avg_hotel_price_per_night',
                      'total_hotel_nights', 'avg_nights_per_stay',
                      'total_rooms_booked', 'avg_rooms_per_booking']

print(f"Hotel trip metrics aggregated: {len(hotel_trips):,} users with hotels")

print("\nOK: User-level aggregation complete")

# %%
print("MERGING USER-LEVEL DATASETS")
print("="*80)

# Start with user info
user_base = user_info.copy()

# Merge session metrics
user_base = user_base.merge(session_metrics, on='user_id', how='left')

# Merge booking metrics
user_base = user_base.merge(booking_metrics, on='user_id', how='left')

# Merge package bookings
user_base = user_base.merge(package_bookings, on='user_id', how='left')
user_base['total_package_bookings'] = user_base['total_package_bookings'].fillna(0).astype(int)

# Merge flight metrics
user_base = user_base.merge(flight_trips, on='user_id', how='left')

# Merge hotel metrics
user_base = user_base.merge(hotel_trips, on='user_id', how='left')

# Add derived metrics
print("\nAdding derived metrics...")

# Calculate tenure
user_base['days_since_signup'] = (pd.Timestamp('2023-04-30') - user_base['sign_up_date']).dt.days
user_base['years_active'] = user_base['days_since_signup'] / 365.25

# Calculate trip counts (considering return flights as 1 trip)
user_base['flight_trips'] = user_base['total_flights_booked'].fillna(0)
user_base['hotel_trips'] = user_base['total_hotels_booked'].fillna(0)

# Total spend
user_base['total_spend'] = (
    user_base['total_flight_spend'].fillna(0) + 
    user_base['total_hotel_spend'].fillna(0)
)

# Cancellation rate
user_base['cancellation_rate'] = user_base['total_cancellations'] / user_base['total_sessions']

# Fill NaN values for users who never booked
fill_zero_cols = ['total_flight_spend', 'avg_flight_fare', 'total_seats_purchased', 
                  'total_bags', 'avg_bags_per_trip', 'return_flight_count',
                  'total_hotel_spend', 'avg_hotel_price_per_night', 'total_hotel_nights',
                  'avg_nights_per_stay', 'total_rooms_booked', 'avg_rooms_per_booking']

for col in fill_zero_cols:
    if col in user_base.columns:
        user_base[col] = user_base[col].fillna(0)

print(f"\nOK: User base created")
print(f"  Shape: {user_base.shape}")
print(f"  Users: {len(user_base):,}")
print(f"  Features: {len(user_base.columns)}")

# Display sample
print("\nSample of user base (first 3 users):")
print(user_base.head(3))

# %% [markdown]
# ## 6. Customer Lifetime Value (CLV) Analysis
#
# Estimate annual CLV based on spending patterns and tenure.

# %%
print("CALCULATING CUSTOMER LIFETIME VALUE (CLV)")
print("="*80)

# Calculate estimated annual CLV
# Formula: (Total Spend / Years Active) = Estimated Annual Spending

# Avoid division by zero - use minimum of 30 days (0.082 years) for very new users
user_base['years_active_adjusted'] = user_base['years_active'].apply(
    lambda x: max(x, 30/365.25)
)

user_base['estimated_annual_clv'] = (
    user_base['total_spend'] / user_base['years_active_adjusted']
)

# CLV quartiles for segmentation
user_base['clv_quartile'] = pd.qcut(
    user_base['estimated_annual_clv'], 
    q=4, 
    labels=[1, 2, 3, 4],
    duplicates='drop'
)

print("\nCLV DISTRIBUTION:")
print("-" * 80)
print(f"  Mean: ${user_base['estimated_annual_clv'].mean():.2f}")
print(f"  Median: ${user_base['estimated_annual_clv'].median():.2f}")
print(f"  Std Dev: ${user_base['estimated_annual_clv'].std():.2f}")
print(f"  Range: ${user_base['estimated_annual_clv'].min():.2f}-${user_base['estimated_annual_clv'].max():.2f}")

print("\nCLV BY QUARTILE:")
print("-" * 80)
clv_quartiles = user_base.groupby('clv_quartile')['estimated_annual_clv'].agg(['count', 'mean', 'min', 'max'])
for quartile, row in clv_quartiles.iterrows():
    print(f"  Q{quartile}: {int(row['count']):,} users | Mean: ${row['mean']:.2f} | Range: ${row['min']:.2f}-${row['max']:.2f}")

# CLV segments
print("\nCLV SEGMENTATION:")
print("-" * 80)
user_base['clv_segment'] = pd.cut(
    user_base['estimated_annual_clv'],
    bins=[0, 500, 1500, 5000, float('inf')],
    labels=['Low Value', 'Medium Value', 'High Value', 'VIP']
)

clv_segment_dist = user_base['clv_segment'].value_counts().sort_index()
for segment, count in clv_segment_dist.items():
    pct = count / len(user_base) * 100
    avg_clv = user_base[user_base['clv_segment'] == segment]['estimated_annual_clv'].mean()
    print(f"  {segment}: {count:,} ({pct:.1f}%) | Avg CLV: ${avg_clv:.2f}")

# Total projected annual value
total_annual_value = user_base['estimated_annual_clv'].sum()
print(f"\nTotal Projected Annual Value: ${total_annual_value:,.2f}")

print("\nOK: CLV analysis complete")

# %%
# CLV visualizations
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# Plot 1: CLV distribution
axes[0, 0].hist(user_base['estimated_annual_clv'], bins=50, color='darkgreen', 
                edgecolor='black', alpha=0.7)
axes[0, 0].axvline(user_base['estimated_annual_clv'].mean(), color='red', 
                   linestyle='--', linewidth=2, 
                   label=f"Mean: ${user_base['estimated_annual_clv'].mean():.0f}")
axes[0, 0].axvline(user_base['estimated_annual_clv'].median(), color='orange', 
                   linestyle='--', linewidth=2, 
                   label=f"Median: ${user_base['estimated_annual_clv'].median():.0f}")
axes[0, 0].set_xlabel('Estimated Annual CLV (USD)', fontweight='bold')
axes[0, 0].set_ylabel('Number of Users', fontweight='bold')
axes[0, 0].set_title('Customer Lifetime Value Distribution', fontweight='bold', fontsize=12)
axes[0, 0].legend()
axes[0, 0].grid(axis='y', alpha=0.3)

# Plot 2: CLV by quartile
clv_quartiles['mean'].plot(kind='bar', ax=axes[0, 1], color='teal', 
                           edgecolor='black', alpha=0.7)
axes[0, 1].set_xlabel('CLV Quartile', fontweight='bold')
axes[0, 1].set_ylabel('Mean Annual CLV (USD)', fontweight='bold')
axes[0, 1].set_title('CLV by Quartile', fontweight='bold', fontsize=12)
axes[0, 1].tick_params(axis='x', rotation=0)
axes[0, 1].grid(axis='y', alpha=0.3)

# Plot 3: CLV segments
clv_segment_dist.plot(kind='bar', ax=axes[1, 0], 
                      color=['#e74c3c', '#f39c12', '#2ecc71', '#9b59b6'],
                      edgecolor='black', alpha=0.7)
axes[1, 0].set_xlabel('CLV Segment', fontweight='bold')
axes[1, 0].set_ylabel('Number of Users', fontweight='bold')
axes[1, 0].set_title('Users by CLV Segment', fontweight='bold', fontsize=12)
axes[1, 0].tick_params(axis='x', rotation=45)
axes[1, 0].grid(axis='y', alpha=0.3)

# Plot 4: CLV vs Total Spend scatter
axes[1, 1].scatter(user_base['total_spend'], user_base['estimated_annual_clv'], 
                   alpha=0.5, c=user_base['years_active'], cmap='viridis', s=20)
axes[1, 1].set_xlabel('Total Spend (USD)', fontweight='bold')
axes[1, 1].set_ylabel('Estimated Annual CLV (USD)', fontweight='bold')
axes[1, 1].set_title('CLV vs Total Spend (colored by tenure)', fontweight='bold', fontsize=12)
axes[1, 1].grid(alpha=0.3)
cbar = plt.colorbar(axes[1, 1].collections[0], ax=axes[1, 1])
cbar.set_label('Years Active', fontweight='bold')

plt.suptitle('Customer Lifetime Value Analysis', fontweight='bold', fontsize=14, y=1.00)
plt.tight_layout()
plt.savefig(f'{FIGURES_EDA}eda_clv_analysis.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"\nOK: Saved: {FIGURES_EDA}eda_clv_analysis.png")

# %% [markdown]
# ## 7. Data Validation & Export

# %%
print("DATA VALIDATION & EXPORT")
print("="*80)

# Validation checks
print("\nDATA QUALITY CHECKS:")
print("-" * 80)
print(f"  Total users: {len(user_base):,}")
print(f"  Total features: {len(user_base.columns)}")
print(f"  Missing user_id: {user_base['user_id'].isna().sum()}")
print(f"  Duplicate user_id: {user_base['user_id'].duplicated().sum()}")

# Check for critical missing values
critical_cols = ['age', 'total_sessions', 'estimated_annual_clv']
print("\nCritical columns (missing values):")
for col in critical_cols:
    missing = user_base[col].isna().sum()
    print(f"  {col}: {missing} ({missing/len(user_base)*100:.2f}%)")

# Summary statistics
print("\nKEY METRICS SUMMARY:")
print("-" * 80)
summary_stats = {
    'Total Users': len(user_base),
    'Avg Age': f"{user_base['age'].mean():.1f} years",
    'Avg Sessions': f"{user_base['total_sessions'].mean():.2f}",
    'Avg CLV': f"${user_base['estimated_annual_clv'].mean():.2f}",
    'Total Annual Value': f"${user_base['estimated_annual_clv'].sum():,.2f}",
    'Users with Bookings': f"{((user_base['total_flights_booked'] > 0) | (user_base['total_hotels_booked'] > 0)).sum():,}",
    'Booking Rate': f"{((user_base['total_flights_booked'] > 0) | (user_base['total_hotels_booked'] > 0)).sum() / len(user_base) * 100:.1f}%"
}

for metric, value in summary_stats.items():
    print(f"  {metric}: {value}")

# Export user base
output_file = f'{DATA_PROCESSED}user_base_complete.csv'
user_base.to_csv(output_file, index=False)

import os
file_size = os.path.getsize(output_file) / 1024**2

print(f"\nOK: Exported: {output_file}")
print(f"  Shape: {user_base.shape}")
print(f"  Size: {file_size:.2f} MB")

# Export summary statistics
summary_df = pd.DataFrame({
    'Metric': list(summary_stats.keys()),
    'Value': list(summary_stats.values())
})

summary_file = f'{DATA_RESULTS_EDA}eda_summary_stats.csv'
summary_df.to_csv(summary_file, index=False)

print(f"\nOK: Exported: {summary_file}")

print("\nOK: Data validation and export complete")

# %%
print("\n" + "="*80)
print("NOTEBOOK 02 SUMMARY: EDA_behavioral_analysis")
print("="*80)

print("\nOK: DELIVERABLES COMPLETED")
print("-" * 80)
print(f"  Cohort data loaded: OK: 5,765 users, 43,344 sessions")
print(f"  Engagement outliers removed: OK: 238 sessions (0.55%)")
print(f"  Demographic analysis: OK: Complete")
print(f"  Booking behavior analysis: OK: Complete")
print(f"  Temporal patterns: OK: Complete")
print(f"  User-level aggregation: OK: Complete")
print(f"  CLV analysis: OK: Complete")
print(f"  Data validation: OK: Complete")
print(f"  Visualizations: OK: Generated (4 figures)")
print(f"  Data exports: OK: Complete")

print("\n" + "="*80)
print("DATA QUALITY IMPROVEMENTS")
print("="*80)
print("ENGAGEMENT OUTLIER REMOVAL:")
print("  - Page clicks outliers: 114 sessions (>66 clicks)")
print("  - Duration outliers: 238 sessions (>8.07 minutes)")
print("  - Total removed: 238 sessions (0.55%)")
print("  - Impact: 7.2% reduction in mean session duration")
print("  - Reason: System limits (120 min, 200 clicks) distorting distributions")
print("  - Result: Cleaner visualizations, more accurate user aggregations")

print("\n" + "="*80)
print("KEY INSIGHTS")
print("="*80)
print("DEMOGRAPHICS:")
print("  - Core age group: 35-44 (36.2%)")
print("  - Gender: 88.1% Female")
print("  - Married: 45.8% | Has Children: 33.0%")
print("  - Avg tenure: 0.27 years (new user base)")

print("\nBOOKING BEHAVIOR:")
print("  - Booking rate: 87.7% of users have booked")
print("  - Package preference: 22.7% book flight + hotel together")
print("  - Return flights: 95.6% prefer round trips")
print("  - Avg bookings: ~2 per user")

print("\nENGAGEMENT PATTERNS:")
print("  - Booked sessions: 2x more clicks (25 vs 11)")
print("  - Peak hour: 7pm (9.6% of sessions)")
print("  - Seasonality: Jan-Mar peak (67% of traffic)")
print("  - Even weekday distribution")
print("  - Avg session: 1.81 min, 14.56 clicks (after outlier removal)")

print("\nCLV INSIGHTS:")
print("  - Mean CLV: $4,135.84")
print("  - 75% High Value or VIP segments")
print("  - Total annual value: $23.8M")
print("  - Q4 worth 20x Q1")

print("\n" + "="*80)
print("OUTPUT FILES CREATED")
print("="*80)
print(f"  1. {DATA_PROCESSED}user_base_complete.csv (5,765 users, 41 features)")
print(f"  2. {DATA_RESULTS_EDA}eda_summary_stats.csv")
print(f"  3. {FIGURES_EDA}eda_demographics.png")
print(f"  4. {FIGURES_EDA}eda_booking_behavior.png")
print(f"  5. {FIGURES_EDA}eda_engagement_temporal.png")
print(f"  6. {FIGURES_EDA}eda_clv_analysis.png")

print("\n" + "="*80)
print("FINAL DATASET")
print("="*80)
print(f"  Users: {session_base['user_id'].nunique():,}")
print(f"  Sessions (cleaned): {len(session_base):,}")
print(f"  Features: 41 user-level metrics")
print(f"  Quality: High (all critical checks passed)")

print("\n" + "="*80)
print("NEXT STEPS")
print("="*80)
print("  Proceed to: 03_FE_core_features.ipynb (Week 2)")
print("  Purpose: Engineer booking, engagement, and financial features")
print("\n" + "="*80)
print(f"Notebook completed: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("="*80)
